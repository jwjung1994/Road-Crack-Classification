# %%
import cv2
import numpy as np
import os
import random
import h5py
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data_directory = "D:/Road Crack Dataset/make_dataset/"
#data_directory = "D:/crack dataset/testing/"
img_size = 128
categories = ["negative", "positive"]
# 0 : negative(no_crack)////// 1 : positive(crack)
training_data = []

# %%
for category in categories:
    path = os.path.join(data_directory, category)
    class_num = categories.index(category)
    print(category +' : '+ str(class_num))
# Out:
# negative : 0
# positive : 1

# %%
def create_training_data():
    for category in categories:
        path = os.path.join(data_directory, category)
        class_num = categories.index(category)
        
        # read and resize the images and append to training_data a list with the image itself and its class number
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE) #   IMREAD_COLOR
            new_array = cv2.resize(img_array, (img_size, img_size))
            training_data.append([new_array, class_num])

# %%
print("Creating training data...")
create_training_data()
print("Training data successfully created!!")

print("Shuffling training data...")
random.shuffle(training_data)
print("Training data successfully shuffled!!")
# Out:
# Creating training data...
# Training data successfully created!!
# Shuffling training data...
# Training data successfully shuffled!!

# %%
X_data = []
y = []

# create X with the features (the images) and y with the targets (labels)
for features, label in training_data:
    X_data.append(features)
    y.append(label)

print("X and y data successfully created!!")

# reshape the image to be on the correct format for tensorflow (nº images, width, height, channels)
print("Reshaping X data...")

#RGB = 3, GRAY = 1로 설정할것
channels = 1
X = np.array(X_data).reshape(len(X_data), img_size, img_size, channels)
print("X data successfully reshaped!!")
# Out:
# X and y data successfully created!!
# Reshaping X data...
# X data successfully reshaped!!

# %%
print("Saving the data...")
hf = h5py.File("dataset/aaa/bbb.hdf5", "w")
hf.create_dataset("X_concrete", data = X, compression = "gzip")
hf.create_dataset("y_concrete", data = y, compression = "gzip")
hf.close()
print("Data successfully saved!!")
# Out:
# Saving the data...
# Data successfully saved!!
