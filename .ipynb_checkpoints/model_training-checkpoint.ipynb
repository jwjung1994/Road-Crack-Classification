# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
print("Loading the data...")
hf = h5py.File('trainset2_1ch.hdf5', 'r') #Replace the three dots with the directory you saved the dataset in
X = np.array(hf.get('X_concrete'))
y = np.array(hf.get("y_concrete"))
hf.close()
print("Data successfully loaded!")

print("Scaling the data...!")
X = X / 255
print("Data successfully scaled!")
# Out:
# Loading the data...
# Data successfully loaded!
# Scaling the data...!
# Data successfully scaled!

# %%
X.shape

# %%
# 7:3 비율로 trainset, testset split
X_test, X = X[:2500], X[2500:]
y_test, y = y[:2500], y[2500:]

# %%
#model training part
model = Sequential()

img_size = 128
channels = 1

model.add(Conv2D(16, (3, 3), activation = "relu", input_shape = (img_size, img_size, channels)))
model.add(Conv2D(16, (3, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(.3))

model.add(Conv2D(32, (3, 3), activation = "relu"))
model.add(Conv2D(32, (3, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(.3))

model.add(Conv2D(64, (3, 3), activation = "relu"))
model.add(Conv2D(64, (3,3 ), activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(.3))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation = "sigmoid"))

print("Compiling the model...")
model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
print("Model successfully compiled!!")

from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience = 10)  # 조기종료 콜백함수

print("Fitting the model...")
hist = model.fit(X, y, batch_size = 20, epochs = 1000, validation_split = .2, callbacks = [early_stopping])
print("Model successfully fitted!!")
# Out:
# Compiling the model...
# Model successfully compiled!!
# Fitting the model...
# Train on 4803 samples, validate on 1201 samples
# Epoch 1/1000
# 4803/4803 [==============================] - 7s 2ms/sample - loss: 0.4833 - accuracy: 0.7789 - val_loss: 0.4508 - val_accuracy: 0.8027
# Epoch 2/1000
# 4803/4803 [==============================] - 3s 621us/sample - loss: 0.3807 - accuracy: 0.8607 - val_loss: 0.3568 - val_accuracy: 0.8593
# Epoch 3/1000
# 4803/4803 [==============================] - 3s 627us/sample - loss: 0.3332 - accuracy: 0.8776 - val_loss: 0.3940 - val_accuracy: 0.8326
# Epoch 4/1000
# 4803/4803 [==============================] - 3s 623us/sample - loss: 0.3125 - accuracy: 0.8894 - val_loss: 0.2752 - val_accuracy: 0.9059
# Epoch 5/1000
# 4803/4803 [==============================] - 3s 626us/sample - loss: 0.2982 - accuracy: 0.8986 - val_loss: 0.2512 - val_accuracy: 0.9134
# Epoch 6/1000
# 4803/4803 [==============================] - 3s 621us/sample - loss: 0.2839 - accuracy: 0.9034 - val_loss: 0.2396 - val_accuracy: 0.9226
# Epoch 7/1000
# 4803/4803 [==============================] - 3s 634us/sample - loss: 0.2632 - accuracy: 0.9115 - val_loss: 0.1966 - val_accuracy: 0.9326
# Epoch 8/1000
# 4803/4803 [==============================] - 3s 632us/sample - loss: 0.2451 - accuracy: 0.9146 - val_loss: 0.5081 - val_accuracy: 0.7968
# Epoch 9/1000
# 4803/4803 [==============================] - 3s 630us/sample - loss: 0.2173 - accuracy: 0.9255 - val_loss: 0.1619 - val_accuracy: 0.9417
# Epoch 10/1000
# 4803/4803 [==============================] - 3s 634us/sample - loss: 0.1995 - accuracy: 0.9309 - val_loss: 0.1794 - val_accuracy: 0.9376
# Epoch 11/1000
# 4803/4803 [==============================] - 3s 628us/sample - loss: 0.1825 - accuracy: 0.9369 - val_loss: 0.1683 - val_accuracy: 0.9467
# Epoch 12/1000
# 4803/4803 [==============================] - 3s 638us/sample - loss: 0.1564 - accuracy: 0.9461 - val_loss: 0.1572 - val_accuracy: 0.9509
# Epoch 13/1000
# 4803/4803 [==============================] - 3s 636us/sample - loss: 0.1475 - accuracy: 0.9511 - val_loss: 0.1550 - val_accuracy: 0.9509
# Epoch 14/1000
# 4803/4803 [==============================] - 3s 637us/sample - loss: 0.1439 - accuracy: 0.9492 - val_loss: 0.1516 - val_accuracy: 0.9459
# Epoch 15/1000
# 4803/4803 [==============================] - 3s 628us/sample - loss: 0.1197 - accuracy: 0.9582 - val_loss: 0.1496 - val_accuracy: 0.9550
# Epoch 16/1000
# 4803/4803 [==============================] - 3s 632us/sample - loss: 0.1191 - accuracy: 0.9615 - val_loss: 0.2081 - val_accuracy: 0.9459
# Epoch 17/1000
# 4803/4803 [==============================] - 3s 633us/sample - loss: 0.1155 - accuracy: 0.9609 - val_loss: 0.1780 - val_accuracy: 0.9425
# Epoch 18/1000
# 4803/4803 [==============================] - 3s 634us/sample - loss: 0.1040 - accuracy: 0.9669 - val_loss: 0.1706 - val_accuracy: 0.9442
# Epoch 19/1000
# 4803/4803 [==============================] - 3s 638us/sample - loss: 0.0973 - accuracy: 0.9675 - val_loss: 0.1513 - val_accuracy: 0.9592s: 0.0
# Epoch 20/1000
# 4803/4803 [==============================] - 3s 635us/sample - loss: 0.0948 - accuracy: 0.9698 - val_loss: 0.1450 - val_accuracy: 0.9600
# Epoch 21/1000
# 4803/4803 [==============================] - 3s 638us/sample - loss: 0.0948 - accuracy: 0.9702 - val_loss: 0.1457 - val_accuracy: 0.9550
# Epoch 22/1000
# 4803/4803 [==============================] - 3s 622us/sample - loss: 0.0867 - accuracy: 0.9721 - val_loss: 0.1475 - val_accuracy: 0.9575
# Epoch 23/1000
# 4803/4803 [==============================] - 3s 631us/sample - loss: 0.0732 - accuracy: 0.9736 - val_loss: 0.1531 - val_accuracy: 0.9584
# Epoch 24/1000
# 4803/4803 [==============================] - 3s 635us/sample - loss: 0.0783 - accuracy: 0.9727 - val_loss: 0.1616 - val_accuracy: 0.9609
# Epoch 25/1000
# 4803/4803 [==============================] - 3s 637us/sample - loss: 0.0688 - accuracy: 0.9773 - val_loss: 0.1662 - val_accuracy: 0.9542
# Epoch 26/1000
# 4803/4803 [==============================] - 3s 631us/sample - loss: 0.0659 - accuracy: 0.9790 - val_loss: 0.1688 - val_accuracy: 0.9584
# Epoch 27/1000
# 4803/4803 [==============================] - 3s 627us/sample - loss: 0.0747 - accuracy: 0.9754 - val_loss: 0.1573 - val_accuracy: 0.9525
# Epoch 28/1000
# 4803/4803 [==============================] - 3s 633us/sample - loss: 0.0588 - accuracy: 0.9808 - val_loss: 0.1564 - val_accuracy: 0.9600
# Epoch 29/1000
# 4803/4803 [==============================] - 3s 635us/sample - loss: 0.0574 - accuracy: 0.9811 - val_loss: 0.1841 - val_accuracy: 0.9575
# Epoch 30/1000
# 4803/4803 [==============================] - 3s 633us/sample - loss: 0.0883 - accuracy: 0.9721 - val_loss: 0.1493 - val_accuracy: 0.9659
# Model successfully fitted!!

# %%
#training 중 train_loss, valid_loss, train_acc, valid_acc 그래프 표현
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label = 'train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label = 'val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label = 'train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label = 'val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()

# %% [markdown]
# ## testset을 이용한 예측 결과

# %%
loss_and_metrics = model.evaluate(X_test, y_test, batch_size=32)

print('loss : ' + str(loss_and_metrics[0]))
print('accuray : ' + str(loss_and_metrics[1]))
# Out:
# 2500/2500 [==============================] - 1s 328us/sample - loss: 0.2128 - accuracy: 0.9648
#
# loss : 0.21280449739098548
# accuray : 0.9648

# %% [markdown]
# ### 예측을 그래프로 표현

# %%
class_names = ["non-crack", "crack"]

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i, :, :, 0]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap="gray")

    predicted_label = np.argmax(predictions_array)
    if true_label == 0:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{}".format(class_names[true_label]), color=color)

# %%
yhat = model.predict_classes(X_test, verbose = 0)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, yhat, y_test, X_test)
plt.show()

# %%
#save the train model
print("Saving the model...")
model.save("trainmodel.model")
print("Model successfully saved!!")
